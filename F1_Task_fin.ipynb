# %% [markdown]
# <a href="https://colab.research.google.com/github/PraneethVasa/CHAT/blob/main/F1_Task_fin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## ***Importing Required Libraries***

# %% [markdown]
# 1. **pandas, numpy**: Used for data manipulation and numerical operations.
# 2. **datetime**: To handle date conversions and calculate recency.
# 3. **random**: To generate random scores for business logic.

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import random

# %% [markdown]
# ## ***SettingUp Constants***

# %% [markdown]
# Defines key parameters:
#
# 1.  alpha, beta: Weights for calculating the combined score (frequency and recency).
# 2. purchasing_power: Represents the consultant’s budget.
# 3. k: Maximum bundle size.
# 4. C_max: Maximum cost allowed for a bundle.
# 5. gamma, delta: Weights for scoring candidates.
# 6. n_categories: Maximum categories per bundle.
# 7. num_bundles: Number of bundles to generate per consultant.

# %%
alpha = 0.4
beta = 0.6
purchasing_power = 100.0
k = 7   # size of bundles
C_max = 100.0
theta = 1
gamma = 0.25
delta = 0.75
n_categories = 7  # max number of categories allowed per bundle
num_bundles = 4  # number of bundles

# %% [markdown]
# Reads a CSV file named '*sample_data_1000_C.csv*' into a DataFrame.

# %%
df = pd.read_csv('/content/sample_data_1000_C.csv')
df.head()
# Out:
#    CODEBELISTA  CODPRODUCTOSAP          DESCATEGORIA DESMARCA  PRECIOOFERTA  \
# 0     44109905       200112294            MAQUILLAJE   CYZONE          9.50
# 1     36949902       200086399            FRAGANCIAS     LBEL         19.95
# 2     49968221       200089498  TRATAMIENTO CORPORAL    ESIKA         36.90
# 3     46114531       210102388            BIJOUTERIE    ESIKA         59.90
# 4     50368645       210100620          COMPLEMENTOS   CYZONE         74.90
#
#   FECHAPROCESO
# 0   2023-02-09
# 1   2023-02-02
# 2   2023-02-10
# 3   2023-02-21
# 4   2023-03-01

# %% [markdown]
# ## ***Data Pre-processing***

# %% [markdown]
# Data Cleaning
# Column names are renamed for clarity.
# Missing values in the category column are filled with "OTHERS."
#
# Dates are converted to datetime format for aggregation.

# %%
#Renaming the columns
column_rename_map={
                "CODEBELISTA": "consultant_id",
                "CODPRODUCTOSAP": "product_id",
                "DESCATEGORIA": "category",
                "DESMARCA": "brand",
                "PRECIOOFERTA": "price",
                "FECHAPROCESO": "date"
            }
df.rename(columns=column_rename_map, inplace=True)
df.head()
# Out:
#    consultant_id  product_id              category   brand  price        date
# 0       44109905   200112294            MAQUILLAJE  CYZONE   9.50  2023-02-09
# 1       36949902   200086399            FRAGANCIAS    LBEL  19.95  2023-02-02
# 2       49968221   200089498  TRATAMIENTO CORPORAL   ESIKA  36.90  2023-02-10
# 3       46114531   210102388            BIJOUTERIE   ESIKA  59.90  2023-02-21
# 4       50368645   210100620          COMPLEMENTOS  CYZONE  74.90  2023-03-01

# %%
# Loop over each column and print unique values
for column in df.columns:
    unique_values = df[column].unique()
    print(f"Unique values in column '{column}': {unique_values}")
# Out:
# Unique values in column 'consultant_id': [44109905 36949902 49968221 46114531 50368645  3441296 50086135 49621434
#  46587790 40764801 45494314 33777957 45697525 34191115 49588232 50476650
#  50349691 45869830 50837122 50843157 48346014 49599102 50639266 50437760
#  49642350 48433154 49330626 48341519 50224287 48765629 46518039 50015882
#  49961014 49434669 44242133 44479885 48823106 44196425 11976964 33090625
#  41317310 39625989 11692060 49864310 50034054 46669258 49794401 42759880
#  49728603 47430550 47948835 49086741 50147800  4623541 43767909 44661489
#  46627121 49931492 49705387 44047470 49975686 44045680 49506570 33905173
#  50052273 49657315 31826446 49566263 46219902 49397003 46611063 30185862
#  49470762 49864469 44413795 33529260 47499070 50014223 48212689 42498750
#  48297765 47097371 49740433 49885083 49931050 49075782 42382701 49794657
#  45680231 34978506 47880688 10459362 42265901 49377649 49561199 49814240
#  39630249 49206860 49389949 50051617 50172864 50291766 46779789 48855490
#  48674135 50302369 49401760 30803868 36649356 48658954 40307516 42567566
#  50409260 47383358 50795365 48893864 47257492 50391108 50852121 46289234
#  50860264 47412552 50432777 38304471 50366901 50680312 50438384 12221789
#  50462889 49703155 50310043 48177719 50697932 50545385 23240475 45325695
#  50935558 49754906 49103301 50496473 50491358 51129296 39061287 50955184
#  50773094 46016947 34216002 35591273 50507157 42670251 39523851 49877986
#  50692213 33999992 50941108 50967689 51181794 50973573  8351554 50974227
#  51254023 51096878 21793760 26864194 51356535 48605184 51448413 51241487
#  51520653 51347056 51056906 50513580 50529959 49521464 50773493 48047378
#  50445577 49819226 48655904 50574822 42909386 50405737 46941012 37789771
#  50387488 49517033 50530272 10576075 39592525 49857217 49583834 50156648
#  48950426 43063650 49222114 51477898 46359186 49746229 49769725 41059117
#  42845353 51843126 49691823 43364677 52027209 52093236 51844726 52046947
#  51940229 51766490 52071712 52108101 39520125 51973836 42829803 52073731
#  51890019 52082706 49711530 24730247 51893042 33740395 44424029 52135567
#  52047269 52252415 52208777 52208297 45579557 52181135 52235367 52249244
#  52216281 52332435 47780152 52317975  9687599 52178282 47266211 52324610
#  52063728 10316898 52142881 52128625 52263344 31344638 32452310 52121175
#  52222087 52307686 52321174 52360757 52324548 52218209 51917480 52335949
#  52341973 52282004 36888067 52280400 10018668 47687314 52105560 52364329
#  52485088 52474183 52478715 35775838 52502403 52508800 52328195 52504589
#  52508843 52373875 44371774 52404940 52486300 44474727 11774652 52559936
#  52385458 34766592 52380553 48904033 52484251 52384451 52567297 52415934
#  52474191  8592470 20312556 49765991 48372104 51614402 11044867 38267000
#  42858498]
# Unique values in column 'product_id': [200112294 200086399 200089498 ... 210106469 210106147 210106146]
# Unique values in column 'category': ['MAQUILLAJE' 'FRAGANCIAS' 'TRATAMIENTO CORPORAL' 'BIJOUTERIE'
#  'COMPLEMENTOS' 'CUIDADO PERSONAL' 'TRATAMIENTO FACIAL'
#  'MUESTRAS COSMETICOS' 'HOGAR' 'VARIOS' 'RELOJES' 'PROMOCION USUARIOS'
#  'ACCESORIOS COSMETICOS' 'LENTES' nan]
# Unique values in column 'brand': ['CYZONE' 'LBEL' 'ESIKA' 'GENERICA' 'FINART']
# Unique values in column 'price': [ 9.5  19.95 36.9  ... 67.98 32.81 21.38]
# Unique values in column 'date': ['2023-02-09' '2023-02-02' '2023-02-10' '2023-02-21' '2023-03-01'
#  '2023-02-07' '2023-02-01' '2023-02-24' '2023-03-07' '2023-07-04'
#  '2023-05-04' '2023-05-05' '2023-01-11' '2023-01-24' '2023-01-26'
#  '2023-01-13' '2023-01-03' '2023-01-23' '2023-01-16' '2023-01-09'
#  '2023-01-19' '2023-01-10' '2023-01-20' '2023-02-03' '2023-02-06'
#  '2023-01-31' '2023-02-08' '2023-02-13' '2023-01-30' '2023-02-14'
#  '2023-02-18' '2023-02-16' '2023-01-17' '2023-01-18' '2023-01-28'
#  '2023-01-27' '2023-01-12' '2023-02-15' '2023-07-05' '2023-06-12'
#  '2023-03-02' '2023-02-28' '2023-06-30' '2023-06-27' '2023-02-27'
#  '2023-03-03' '2023-06-28' '2023-06-09' '2023-05-03' '2023-05-23'
#  '2023-09-08' '2023-05-25' '2023-08-08' '2023-09-13' '2023-08-11'
#  '2023-07-07' '2023-09-22' '2023-09-01' '2023-09-06' '2023-09-12'
#  '2023-08-14' '2023-09-21' '2023-09-14' '2023-09-25' '2023-10-04'
#  '2023-10-11' '2023-10-05' '2023-10-09' '2023-10-30' '2023-10-26'
#  '2023-10-16' '2023-11-03' '2023-10-31' '2023-10-27' '2023-11-06'
#  '2023-11-20' '2023-11-23' '2023-11-17' '2023-11-21' '2023-12-06'
#  '2023-11-24' '2023-07-24' '2023-12-19' '2023-12-05' '2023-12-12'
#  '2023-12-15' '2023-11-16' '2023-11-02' '2023-12-07' '2023-07-31'
#  '2023-05-22' '2023-07-20' '2023-09-04' '2023-07-26' '2023-10-13'
#  '2023-07-18' '2023-07-01' '2023-08-28' '2023-07-06' '2023-08-09'
#  '2023-08-21' '2023-10-06' '2023-04-05' '2023-04-10' '2023-03-16'
#  '2023-03-31' '2023-04-22' '2023-03-27' '2023-01-06' '2023-08-04'
#  '2023-07-22' '2023-08-02' '2023-07-25' '2023-08-10' '2023-08-01'
#  '2023-07-27' '2022-12-26' '2023-04-03' '2023-06-01' '2023-05-08'
#  '2023-06-07' '2022-12-28' '2023-04-17' '2023-05-29' '2023-02-22'
#  '2023-03-24' '2023-04-25' '2023-04-01' '2023-02-23' '2023-04-28'
#  '2023-04-26' '2023-03-17' '2022-12-22' '2023-04-12' '2023-05-02'
#  '2023-04-04' '2022-12-30' '2023-06-14' '2023-04-27' '2023-04-29'
#  '2022-12-16' '2022-12-15' '2023-04-13' '2023-04-11' '2023-03-23'
#  '2023-04-08' '2023-05-09' '2023-07-10' '2023-08-31' '2023-07-03'
#  '2023-09-18' '2023-04-14' '2023-07-13' '2023-07-21' '2023-06-26'
#  '2023-04-18' '2023-03-20' '2023-03-14' '2023-05-11' '2023-04-07'
#  '2023-03-22' '2023-03-21' '2023-04-20' '2023-03-08' '2022-12-27'
#  '2023-05-10' '2023-03-15' '2023-06-03' '2023-05-30' '2023-05-17'
#  '2023-06-05' '2023-06-02' '2023-05-15' '2022-12-23' '2023-01-02'
#  '2023-06-20' '2023-03-13' '2023-06-19' '2023-05-06' '2023-06-16'
#  '2023-04-24' '2023-06-08' '2022-12-19' '2022-12-20' '2023-03-06'
#  '2023-10-10' '2023-05-18' '2023-06-15' '2023-03-28' '2023-06-06'
#  '2023-05-26' '2022-12-17' '2022-12-12' '2023-01-04' '2022-12-14'
#  '2023-07-17' '2023-12-13' '2023-11-27' '2023-12-04' '2023-11-22'
#  '2023-10-02' '2023-09-26' '2023-09-23' '2023-09-19' '2023-01-25'
#  '2023-02-17' '2023-09-11' '2023-11-15' '2023-02-20' '2022-12-21'
#  '2023-01-05' '2023-11-07' '2023-10-20' '2023-11-13' '2024-02-12'
#  '2024-04-08' '2024-04-22' '2024-02-01' '2024-04-05' '2024-02-05'
#  '2024-04-09' '2024-04-24' '2024-04-11' '2023-12-26' '2024-04-29'
#  '2024-02-06' '2024-03-19' '2024-01-02' '2024-04-16' '2024-01-18'
#  '2023-12-29' '2024-01-22' '2024-01-19' '2024-02-02' '2024-01-08'
#  '2024-03-08' '2024-03-04' '2024-04-26' '2024-03-01' '2024-03-18'
#  '2024-01-17' '2024-02-23' '2024-01-15' '2024-04-10' '2024-02-14'
#  '2024-02-26' '2024-02-28' '2024-03-05' '2024-02-20' '2024-02-13'
#  '2024-02-22' '2024-03-25' '2024-03-13' '2024-03-12' '2024-03-21'
#  '2024-01-31' '2024-02-09' '2024-03-15' '2024-05-21' '2024-05-22'
#  '2024-05-24' '2024-05-15' '2024-05-16' '2024-06-05' '2024-06-11'
#  '2024-06-12' '2024-06-06' '2024-05-17' '2024-05-27' '2024-05-14'
#  '2024-06-10' '2024-05-30' '2024-06-20' '2024-05-06' '2024-05-29'
#  '2024-06-07' '2024-06-04' '2024-06-18' '2024-05-23' '2024-06-17'
#  '2024-07-03' '2024-06-24' '2024-07-02' '2024-06-26' '2024-06-28'
#  '2024-05-20' '2024-05-13' '2024-07-25' '2024-07-01' '2024-07-11'
#  '2024-07-12' '2024-06-25' '2024-07-05' '2024-07-09' '2024-07-17'
#  '2024-07-19' '2024-07-08' '2024-07-22' '2024-07-15' '2024-07-23'
#  '2024-07-24' '2024-07-30' '2024-08-12' '2024-07-31' '2024-08-14'
#  '2024-08-20' '2024-08-27' '2024-08-29' '2024-08-28' '2024-09-10'
#  '2024-09-19' '2024-07-26' '2024-09-02' '2024-08-06' '2024-08-13'
#  '2024-08-22' '2024-08-30' '2024-08-23' '2024-08-02' '2024-08-21'
#  '2024-08-16' '2024-08-15' '2024-08-19' '2024-08-09' '2024-08-01'
#  '2024-09-18' '2024-09-12' '2024-09-17' '2024-10-10' '2024-10-02'
#  '2024-10-07' '2024-10-09' '2024-10-03' '2024-10-01' '2024-10-04'
#  '2024-10-23' '2024-10-28' '2024-10-14' '2024-10-21' '2024-10-29'
#  '2024-10-31' '2024-10-24' '2024-10-25' '2024-10-17' '2024-11-21'
#  '2024-11-19' '2024-11-14' '2024-11-18' '2024-11-20' '2024-11-15'
#  '2022-12-29' '2023-01-07' '2023-05-19' '2023-06-13' '2023-05-12'
#  '2023-03-10' '2023-08-17' '2023-08-15' '2023-10-03' '2023-10-12'
#  '2023-08-29' '2023-10-23' '2023-12-11' '2023-08-16' '2023-07-19'
#  '2023-08-18' '2023-12-14' '2023-12-18' '2023-09-15' '2023-11-14'
#  '2023-11-29' '2023-10-25' '2023-10-24' '2023-10-28' '2023-10-17'
#  '2023-10-18' '2023-08-19' '2023-08-03' '2023-09-20' '2023-09-07'
#  '2023-09-05' '2023-05-24' '2023-07-12' '2023-12-08' '2023-06-21'
#  '2023-03-09' '2023-04-19' '2023-05-31' '2023-03-11' '2024-02-07'
#  '2024-04-30' '2023-09-28' '2023-08-05' '2024-04-15' '2024-04-02'
#  '2024-04-25' '2024-02-27' '2024-02-29' '2024-01-16' '2024-01-11'
#  '2024-01-23' '2024-02-08' '2024-01-25' '2024-01-29' '2023-12-27'
#  '2024-03-20' '2023-12-20' '2023-12-21' '2023-12-22' '2024-05-02'
#  '2024-04-12' '2024-01-04' '2024-01-12' '2024-05-07' '2024-05-10'
#  '2024-05-03' '2024-04-18' '2024-04-23' '2024-04-17' '2024-07-04'
#  '2024-07-16' '2024-08-08' '2024-08-05' '2024-08-07' '2024-09-05'
#  '2024-09-16' '2024-09-03' '2024-09-04' '2024-09-09' '2024-09-26'
#  '2024-09-30' '2024-09-23' '2024-10-15' '2024-10-11' '2024-09-20'
#  '2024-10-30' '2024-10-08' '2024-09-25' '2024-11-13' '2024-11-04'
#  '2024-11-26' '2024-11-25' '2024-11-27' '2024-11-06' '2023-05-16'
#  '2023-12-09' '2023-07-11' '2023-03-29' '2023-03-30' '2023-08-24'
#  '2023-08-23' '2023-08-22' '2023-08-30' '2023-08-25' '2023-08-26'
#  '2023-12-02' '2024-03-22' '2023-07-14' '2023-12-28' '2024-04-04'
#  '2024-06-13' '2024-06-03' '2024-06-27' '2024-07-18' '2024-09-11'
#  '2024-09-13' '2024-09-06' '2024-09-24' '2024-10-22' '2024-11-05'
#  '2024-10-16' '2024-11-22' '2023-02-11' '2023-06-10' '2023-08-07'
#  '2024-01-03' '2024-08-26' '2024-09-27' '2024-12-18' '2023-05-27'
#  '2024-04-20' '2024-01-30' '2024-06-14' '2024-12-13' '2023-09-02'
#  '2023-09-09' '2023-05-20' '2024-03-07' '2024-03-30' '2024-05-08'
#  '2024-11-07' '2024-12-16' '2024-12-10' '2024-02-10' '2023-06-22'
#  '2023-11-08' '2024-11-12']

# %%
#Filling Null Values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36310 entries, 0 to 36309
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   consultant_id  36310 non-null  int64
#  1   product_id     36310 non-null  int64
#  2   category       36228 non-null  object
#  3   brand          36310 non-null  object
#  4   price          36310 non-null  float64
#  5   date           36310 non-null  object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 1.7+ MB

# %%
df['category'].fillna('OTHERS', inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36310 entries, 0 to 36309
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   consultant_id  36310 non-null  int64
#  1   product_id     36310 non-null  int64
#  2   category       36310 non-null  object
#  3   brand          36310 non-null  object
#  4   price          36310 non-null  float64
#  5   date           36310 non-null  object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 1.7+ MB
# <ipython-input-7-d823663f0706>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['category'].fillna('OTHERS', inplace=True)

# %%
# Convert `date` column to datetime
df["date"] = pd.to_datetime(df["date"], errors="coerce")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36310 entries, 0 to 36309
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   consultant_id  36310 non-null  int64
#  1   product_id     36310 non-null  int64
#  2   category       36310 non-null  object
#  3   brand          36310 non-null  object
#  4   price          36310 non-null  float64
#  5   date           36310 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(2), object(2)
# memory usage: 1.7+ MB

# %% [markdown]
# **Daily Aggregation**
# Groups data by consultant_id and date to compute frequency and daily_total_spent

# %%
# Perform daily aggregation
group_by_columns = ["consultant_id", "date"]
daily_agg = df.groupby(group_by_columns, as_index=False).agg({
    "product_id": "count",
    "price": "sum"
})

# Rename columns for clarity
daily_agg.rename(columns={
    "product_id": "frequency",
    "price": "daily_total_spent"
}, inplace=True)

daily_agg.head()
# Out:
#    consultant_id       date  frequency  daily_total_spent
# 0        3441296 2022-12-27         10             263.40
# 1        3441296 2023-02-07          8             273.30
# 2        3441296 2023-02-15          1              23.90
# 3        3441296 2023-02-28          7             261.45
# 4        3441296 2023-04-11         17             391.10

# %% [markdown]
# **IQR and Purchasing Power** Interquartile Range (IQR) is calculated for daily_total_spent to identify spending patterns.
# average_purchasing_power is set to Q3 (75th percentile of spending).

# %%
# Calculate IQR for daily_total_spent
Q1 = np.percentile(daily_agg["daily_total_spent"], 25)
Q3 = np.percentile(daily_agg["daily_total_spent"], 75)
IQR = Q3 - Q1

# Add average purchasing power (Q3) as a new column
daily_agg["average_purchasing_power"] = Q3

# %% [markdown]
# **Merge Aggregates**
# 1. Daily aggregates are merged back into the main dataset.
# 2. Recency is calculated as days since the last purchase.

# %%
# Merge the daily aggregates back into the original DataFrame
df = pd.merge(df, daily_agg, on=group_by_columns, how="left")
df.head()
# Out:
#    consultant_id  product_id              category   brand  price       date  \
# 0       44109905   200112294            MAQUILLAJE  CYZONE   9.50 2023-02-09
# 1       36949902   200086399            FRAGANCIAS    LBEL  19.95 2023-02-02
# 2       49968221   200089498  TRATAMIENTO CORPORAL   ESIKA  36.90 2023-02-10
# 3       46114531   210102388            BIJOUTERIE   ESIKA  59.90 2023-02-21
# 4       50368645   210100620          COMPLEMENTOS  CYZONE  74.90 2023-03-01
#
#    frequency  daily_total_spent  average_purchasing_power
# 0         17             427.40                   430.195
# 1         16             403.90                   430.195
# 2         21             406.30                   430.195
# 3         11             469.10                   430.195
# 4          5             202.55                   430.195

# %%
# Calculate recency in days
current_date = datetime.now()
df["recency"] = (current_date - df["date"]).dt.days
df.head()
# Out:
#    consultant_id  product_id              category   brand  price       date  \
# 0       44109905   200112294            MAQUILLAJE  CYZONE   9.50 2023-02-09
# 1       36949902   200086399            FRAGANCIAS    LBEL  19.95 2023-02-02
# 2       49968221   200089498  TRATAMIENTO CORPORAL   ESIKA  36.90 2023-02-10
# 3       46114531   210102388            BIJOUTERIE   ESIKA  59.90 2023-02-21
# 4       50368645   210100620          COMPLEMENTOS  CYZONE  74.90 2023-03-01
#
#    frequency  daily_total_spent  average_purchasing_power  recency
# 0         17             427.40                   430.195      694
# 1         16             403.90                   430.195      701
# 2         21             406.30                   430.195      693
# 3         11             469.10                   430.195      682
# 4          5             202.55                   430.195      674

# %% [markdown]
# **Normalization Frequency and Recency Normalization**:
# Converts raw values to a range between 0 and 1.
# Handles edge cases where all values are identical.
#
# Recency is calculated as days since the last purchase.

# %%
# Normalize frequency
freq_min = df["frequency"].min()
freq_max = df["frequency"].max()

if freq_min != freq_max:
    df["frequency_normalized"] = (df["frequency"] - freq_min) / (freq_max - freq_min)
else:
    df["frequency_normalized"] = 0.5

# %%
# Normalize recency
rec_min = df["recency"].min()
rec_max = df["recency"].max()
ddf?
if rec_min != rec_max:
    df["recency_normalized"] = (df["recency"] - rec_min) / (rec_max - rec_min)
else:
    df["recency_normalized"] = 0.5
# Out:
# Object `ddf` not found.

# %% [markdown]
# **Consultant-Level Metrics total_spent**: Total spending by each consultant.
#
# **purchase_frequency**: Total number of purchases.
#
# **unique_products**: Number of unique products purchased.

# %%
# Consultant-level metrics
df["total_spent"] = df.groupby("consultant_id")["price"].transform("sum")
df["purchase_frequency"] = df.groupby("consultant_id")["product_id"].transform("count")
df["unique_products"] = df.groupby("consultant_id")["product_id"].transform("nunique")

# %%
df.head()
# Out:
#    consultant_id  product_id              category   brand  price       date  \
# 0       44109905   200112294            MAQUILLAJE  CYZONE   9.50 2023-02-09
# 1       36949902   200086399            FRAGANCIAS    LBEL  19.95 2023-02-02
# 2       49968221   200089498  TRATAMIENTO CORPORAL   ESIKA  36.90 2023-02-10
# 3       46114531   210102388            BIJOUTERIE   ESIKA  59.90 2023-02-21
# 4       50368645   210100620          COMPLEMENTOS  CYZONE  74.90 2023-03-01
#
#    frequency  daily_total_spent  average_purchasing_power  recency  \
# 0         17             427.40                   430.195      694
# 1         16             403.90                   430.195      701
# 2         21             406.30                   430.195      693
# 3         11             469.10                   430.195      682
# 4          5             202.55                   430.195      674
#
#    frequency_normalized  recency_normalized  total_spent  purchase_frequency  \
# 0              0.280702            0.919946      4548.33                 159
# 1              0.263158            0.929444      3459.60                 116
# 2              0.350877            0.918589      3674.05                 137
# 3              0.175439            0.903664      6815.04                 161
# 4              0.070175            0.892809      9109.95                 482
#
#    unique_products
# 0              125
# 1              102
# 2              120
# 3              143
# 4              280

# %%
df.to_csv("preprocessed_data_1000_C.csv", index=False)

# %% [markdown]
# ## ***Combined Score for each row based on normalized frequency and recency***

# %% [markdown]
# **Combined Score** :
# A weighted combination of normalized frequency and recency
#
# **combined_score** = alpha * normalized_f + beta * normalized_r

# %%
df = pd.read_csv('/content/preprocessed_data_1000_C.csv')

def normalize(value, min_value, max_value):
    if min_value == max_value:
        return 0
    return (value - min_value) / (max_value - min_value)

min_f = df['purchase_frequency'].min()
max_f = df['purchase_frequency'].max()
min_r = df['recency'].min()
max_r = df['recency'].max()

df['normalized_f'] = df['purchase_frequency'].apply(lambda x: normalize(x, min_f, max_f))
df['normalized_r'] = df['recency'].apply(lambda x: normalize(x, min_r, max_r))
df['combined_score'] = (alpha * df['normalized_f']) + (beta * df['normalized_r'])
df.head()
# Out:
#    consultant_id  product_id              category   brand  price        date  \
# 0       44109905   200112294            MAQUILLAJE  CYZONE   9.50  2023-02-09
# 1       36949902   200086399            FRAGANCIAS    LBEL  19.95  2023-02-02
# 2       49968221   200089498  TRATAMIENTO CORPORAL   ESIKA  36.90  2023-02-10
# 3       46114531   210102388            BIJOUTERIE   ESIKA  59.90  2023-02-21
# 4       50368645   210100620          COMPLEMENTOS  CYZONE  74.90  2023-03-01
#
#    frequency  daily_total_spent  average_purchasing_power  recency  \
# 0         17             427.40                   430.195      694
# 1         16             403.90                   430.195      701
# 2         21             406.30                   430.195      693
# 3         11             469.10                   430.195      682
# 4          5             202.55                   430.195      674
#
#    frequency_normalized  recency_normalized  total_spent  purchase_frequency  \
# 0              0.280702            0.919946      4548.33                 159
# 1              0.263158            0.929444      3459.60                 116
# 2              0.350877            0.918589      3674.05                 137
# 3              0.175439            0.903664      6815.04                 161
# 4              0.070175            0.892809      9109.95                 482
#
#    unique_products  normalized_f  normalized_r  combined_score
# 0              125      0.208995      0.919946        0.635565
# 1              102      0.152116      0.929444        0.618513
# 2              120      0.179894      0.918589        0.623111
# 3              143      0.211640      0.903664        0.626854
# 4              280      0.636243      0.892809        0.790183

# %% [markdown]
# **select_anchor_product(df)**:
# Finds the product with the highest combined_score in the DataFrame, serving as the bundle's starting point.
#
# **generate_candidates(bundle, df)**:
# Returns products not already in the bundle by filtering out existing product IDs.
#
# **category_score(product, bundle)**:
# Checks if a product's category exists in the bundle, returning 1 for a match or 0 otherwise.
#
# **business_score(product)**:
# Generates a random score for a product as a placeholder for advanced business logic.

# %%
def select_anchor_product(df):
        return df.loc[df['combined_score'].idxmax()]

def generate_candidates(bundle, df):
        bundle_product_ids = {p['product_id'] for p in bundle}
        return df[~df['product_id'].isin(bundle_product_ids)]

def category_score(product, bundle):
    return 1 if product['category'] in [b['category'] for b in bundle] else 0

def business_score(product):
    return random.random()

# %% [markdown]
# **score_candidates(candidates, bundle)**:
# Computes a composite score for candidate products based on their category match with the bundle and business logic scores.
#
# **build_bundle(df, anchor_product, purchasing_power, k, C_max, theta, n_categories)**:
# Constructs a product bundle starting with the anchor product, adhering to constraints like max size, cost threshold, and category limits.

# %%
def score_candidates(candidates, bundle):
        candidates = candidates.copy()
        candidates['category_score'] = candidates.apply(lambda p: category_score(p, bundle), axis=1)
        candidates['business_score'] = candidates.apply(business_score, axis=1)
        candidates['score'] = gamma * candidates['category_score'] + delta * candidates['business_score']
        return candidates

def build_bundle(df, anchor_product, purchasing_power, k, C_max, theta, n_categories):

        bundle = [anchor_product]
        current_total_cost = anchor_product['price']
        categories_in_bundle = {anchor_product['category']}

        # Exclude the anchor product from candidates
        candidates = df[df['product_id'] != anchor_product['product_id']]
        candidates = score_candidates(candidates, bundle)
        candidates = candidates[candidates['price'] <= theta * C_max].sort_values(by='score', ascending=False)

        for _, candidate in candidates.iterrows():
            if len(bundle) >= k:
                break
            if candidate['category'] in categories_in_bundle:
                # n_categories = 1 => do not add new categories
                if current_total_cost + candidate['price'] <= C_max:
                    bundle.append(candidate)
                    current_total_cost += candidate['price']
                    # We do not add a new category if n_categories=1
            else:
                # If your logic allows new category, incorporate that here
                pass

        return bundle

# %% [markdown]
# **Purpose:** This below snippet generates multiple product bundles for each consultant.
#
# **Logic:**
#
# 1. Iterates through each consultant's products (consultant_id).
# 2. For each consultant, creates a specified number of bundles (num_bundles).
# 3. Selects an anchor product using select_anchor_product.
# 4. Constructs a bundle using build_bundle, considering constraints like size, cost, and category limits.
# 5. Assigns a unique bundle ID, consultant ID, and flags the anchor product (is_anchor).
# 5. Appends all products in the bundle to the bundles list with metadata.

# %%
bundles = []
for consultant_id, group in df.groupby("consultant_id"):
            for bundle_index in range(num_bundles):
                anchor_product = select_anchor_product(group)
                bundle = build_bundle(
                    group,
                    anchor_product,
                    purchasing_power,  # from config
                    k,
                    C_max,
                    theta,
                    n_categories
                )
                unique_bundle_id = f"{consultant_id}_Bundle_{bundle_index+1}"
                for idx, product in enumerate(bundle):
                    product_copy = product.copy()
                    product_copy["consultant_id"] = consultant_id
                    product_copy["bundle_id"] = unique_bundle_id
                    product_copy["is_anchor"] = 1 if idx == 0 else 0
                    bundles.append(product_copy)

# %%
bundles
# Out:
# [consultant_id                        3441296
#  product_id                         200095159
#  category                    CUIDADO PERSONAL
#  brand                                  ESIKA
#  price                                   7.38
#  date                              2022-12-27
#  frequency                                 10
#  daily_total_spent                      263.4
#  average_purchasing_power             430.195
#  recency                                  738
#  frequency_normalized                0.157895
#  recency_normalized                  0.979647
#  total_spent                          7206.76
#  purchase_frequency                       261
#  unique_products                          194
#  normalized_f                        0.343915
#  normalized_r                        0.979647
#  combined_score                      0.725354
#  bundle_id                   3441296_Bundle_1
#  is_anchor                                  1
#  Name: 1793, dtype: object,
#  consultant_id                        3441296
#  product_id                         200078931
#  category                    CUIDADO PERSONAL
#  brand                                  ESIKA
#  price                                  13.27
#  date                              2023-06-08
#  frequency                                 16
#  daily_total_spent                      385.9
#  average_purchasing_power             430.195
#  recency                                  575
#  frequency_normalized                0.263158
#  recency_normalized                   0.75848
#  total_spent                          7206.76
#  purchase_frequency                       261
#  unique_products                          194
#  normalized_f                        0.343915
#  normalized_r                         0.75848
#  combined_score                      0.592654
#  category_score                             1
#  business_score                      0.984574
#  score                               0.988431
#  bundle_id                   3441296_Bundle_1
#  is_anchor                                  0
#  Name: 18988, dtype: object,
#  consultant_id                        3441296
#  product_id                         200064341
#  category                    CUIDADO PERSONAL
#  brand                                  ESIKA
#  price                                   21.9
#  date                              2022-12-27
#  frequency                                 10
#  daily_total_spent                      263.4
#  average_purchasing_power             430.195
#  recency                                  738
#  frequency_normalized                0.157895
#  recency_normalized                  0.979647
#  total_spent                          7206.76
#  purchase_frequency                       261
#  unique_products                          194
#  normalized_f                        0.343915
#  normalized_r                        0.979647
#  combined_score                      0.725354
#  category_score                             1
#  business_score                      0.890042
#  score                               0.917532
#  bundle_id                   3441296_Bundle_1
#  is_anchor                                  0
#  Name: 27276, dtype: object,
#  consultant_id                        3441296
#  product_id                         200108807
#  category                    CUIDADO PERSONAL
#  brand                                  ESIKA
#  price                                   7.38
#  date                              2024-07-03
#  frequency                                 16
#  daily_total_spent                     354.53
#  average_purchasing_power             430.195
#  recency                                  184
#  frequency_normalized                0.263158
#  recency_normalized                  0.227951
#  total_spent                          7206.76
#  purchase_frequency                       261
#  unique_products                          194
#  normalized_f                        0.343915
#  normalized_r                        0.227951
#  combined_score                      0.274337
#  category_score                             1
#  business_score                      0.884674
#  score                               0.913505
#  bundle_id                   3441296_Bundle_1
#  is_anchor                                  0
#  Name: 3149, dtype: object,
#  consultant_id                        3441296
#  product_id                         200095465
#  category                    CUIDADO PERSONAL
#  brand                                  ESIKA
#  price                                   11.9
#  date                              2023-06-08
#  frequency                                 16
#  daily_total_spent                      385.9
#  average_purchasing_power             430.195
#  recency                                  575
#  frequency_normalized                0.263158
#  recency_normalized                   0.75848
#  total_spent                          7206.76
#  purchase_frequency                       261
#  unique_products                          194
#  normalized_f                        0.343915
#  normalized_r                         0.75848
#  combined_score                      0.592654
#  category_score                             1
#  business_score                      0.861828
#  score                               0.896371
#  bundle_id                   3441296_Bundle_1
#  is_anchor                                  0
#  Name: 22714, dtype: object,
#  consultant_id                        3441296
#  product_id                         200090349
#  category                    CUIDADO PERSONAL
#  brand                                  ESIKA
#  price                                   23.9
#  date                              2023-02-07
#  frequency                                  8
#  daily_total_spent                      273.3
#  average_purchasing_power             430.195
#  recency                                  696
#  frequency_normalized                0.122807
#  recency_normalized                  0.922659
#  total_spent                          7206.76
#  purchase_frequency                       261
#  unique_products                          194
#  normalized_f                        0.343915
#  normalized_r                        0.922659
#  combined_score                      0.691162
#  category_score                             1
#  business_score                      0.855953
#  score                               0.891965
#  bundle_id                   3441296_Bundle_1
#  is_anchor                                  0
#  Name: 5, dtype: object,
#  consultant_id                        3441296
#  product_id                         200095420
#  category                    CUIDADO PERSONAL
#  brand                                  ESIKA
#  price                                   7.38
#  date                              2023-08-15
#  frequency                                 11
#  daily_total_spent                     156.66
#  average_purchasing_power             430.195
#  recency                                  507
#  frequency_normalized                0.175439
#  recency_normalized                  0.666214
#  total_spent                          7206.76
#  purchase_frequency                       261
#  unique_products                          194
#  normalized_f                        0.343915
#  normalized_r                        0.666214
#  combined_score                      0.537295
#  category_score                             1
#  business_score                      0.827558
#  score                               0.870668
#  bundle_id                   3441296_Bundle_1
#  is_anchor                                  0
#  Name: 13374, dtype: object,
#  consultant_id                        3441296
#  product_id                         200095159
#  category                    CUIDADO PERSONAL
#  brand                                  ESIKA
#  price                                   7.38
#  date                              2022-12-27
#  frequency                                 10
#  daily_total_spent                      263.4
#  average_purchasing_power             430.195
#  recency                                  738
#  frequency_normalized                0.157895
#  recency_normalized                  0.979647
#  total_spent                          7206.76
#  purchase_frequency                       261
#  unique_products                          194
#  normalized_f                        0.343915
#  normalized_r                        0.979647
#  combined_score                      0.725354
#  bundle_id                   3441296_Bundle_2
#  is_anchor                                  1
#  Name: 1793, dtype: object,
#  consultant_id                        3441296
#  product_id                         200095430
#  category                    CUIDADO PERSONAL
#  brand                                 CYZONE
#  price                                   6.69
#  date                              2023-04-11
#  frequency                                 17
#  daily_total_spent                      391.1
#  average_purchasing_power             430.195
#  recency                                  633
#  frequency_normalized                0.280702
#  recency_normalized                  0.837178
#  total_spent                          7206.76
#  purchase_frequency                       261
#  unique_products                          194
#  normalized_f                        0.343915
#  normalized_r                        0.837178
#  combined_score                      0.639873
#  category_score                             1
#  business_score                      0.983749
#  score                               0.987812
#  bundle_id                   3441296_Bundle_2
#  is_anchor                                  0
#  Name: 10832, dtype: object,
#  consultant_id                        3441296
#  product_id                         200105188
#  category                    CUIDADO PERSONAL
#  brand                                  ESIKA
#  price                                   7.38
#  date                              2022-12-27
#  frequency                                 10
#  daily_total_spent                      263.4
#  average_purchasing_power             430.195
#  recency                                  738
#  frequency_normalized                0.157895
#  recency_normalized                  0.979647
#  total_spent                          7206.76
#  purchase_frequency                       261
#  unique_products                          194
#  normalized_f                        0.343915
#  normalized_r                        0.979647
#  combined_score                      0.725354
#  category_score                             1
#  business_score                      0.973168
#  score                               0.979876
#  bundle_id                   3441296_Bundle_2
#  is_anchor                                  0
#  Name: 8893, dtype: object,
#  consultant_id                        3441296
#  product_id                         200103452
#  category                    CUIDADO PERSONAL
#  brand                                   LBEL
#  price                                   7.38
#  date                              2024-07-03
#  frequency                                 16
#  daily_total_spent                     354.53
#  average_purchasing_power             430.195
#  recency                                  184
#  frequency_normalized                0.263158
#  recency_normalized                  0.227951
#  total_spent                          7206.76
#  purchase_frequency                       261
#  unique_products                          194
#  normalized_f                        0.343915
#  normalized_r                        0.227951
#  combined_score                      0.274337
#  category_score                             1
#  business_score                      0.948284
#  score                               0.961213
#  bundle_id                   3441296_Bundle_2
#  is_anchor                                  0
#  Name: 3196, dtype: object,
#  consultant_id                        3441296
#  product_id                         200095170
#  category                    CUIDADO PERSONAL
#  brand                                  ESIKA
#  price                                   7.38
#  date                              2022-12-27
#  frequency                                 10
#  daily_total_spent                      263.4
#  average_purchasing_power             430.195
#  recency                                  738
#  frequency_normalized                0.157895
#  recency_normalized                  0.979647
#  total_spent                          7206.76
#  purchase_frequency                       261
#  unique_products                          194
#  normalized_f                        0.343915
#  normalized_r                        0.979647
#  combined_score                      0.725354
#  category_score                             1
#  business_score                      0.919116
#  score                               0.939337
#  bundle_id                   3441296_Bundle_2
#  is_anchor                                  0
#  Name: 8843, dtype: object,
#  consultant_id                        3441296
#  product_id                         200090337
#  category                    CUIDADO PERSONAL
#  brand                                  ESIKA
#  price                                   23.9
#  date                              2023-04-11
#  frequency                                 17
#  daily_total_spent                      391.1
#  average_purchasing_power             430.195
#  recency                                  633
#  frequency_normalized                0.280702
#  recency_normalized                  0.837178
#  total_spent                          7206.76
#  purchase_frequency                       261
#  unique_products                          194
#  normalized_f                        0.343915
#  normalized_r                        0.837178
#  combined_score                      0.639873
#  category_score                             1
#  business_score                      0.817811
#  score                               0.863358
#  bundle_id                   3441296_Bundle_2
#  is_anchor                                  0
#  Name: 28897, dtype: object,
#  consultant_id                        3441296
#  product_id                         200095382
#  category                    CUIDADO PERSONAL
#  brand                                  ESIKA
#  price                                   7.38
#  date                              2023-08-15
#  frequency                                 11
#  daily_total_spent                     156.66
#  average_purchasing_power             430.195
#  recency                                  507
#  frequency_normalized                0.175439
#  recency_normalized                  0.666214
#  total_spent                          7206.76
#  purchase_frequency                       261
#  unique_products                          194
#  normalized_f                        0.343915
#  normalized_r                        0.666214
#  combined_score                      0.537295
#  category_score                             1
#  business_score                      0.798279
#  score                                0.84871
#  bundle_id                   3441296_Bundle_2
#  is_anchor                                  0
#  Name: 13380, dtype: object,
#  consultant_id                        3441296
#  product_id                         200095159
#  category                    CUIDADO PERSONAL
#  brand                                  ESIKA
#  price                                   7.38
#  date                              2022-12-27
#  frequency                                 10
#  daily_total_spent                      263.4
#  average_purchasing_power             430.195
#  recency                                  738
#  frequency_normalized                0.157895
#  recency_normalized                  0.979647
#  total_spent                          7206.76
#  purchase_frequency                       261
#  unique_products                          194
#  normalized_f                        0.343915
#  normalized_r                        0.979647
#  combined_score                      0.725354
#  bundle_id                   3441296_Bundle_3
#  is_anchor                                  1
#  Name: 1793, dtype: object,
#  consultant_id                        3441296
#  product_id                         200103025
#  category                    CUIDADO PERSONAL
#  brand                                  ESIKA
#  price                                  24.98
#  date                              2023-08-15
#  frequency                                 11
#  daily_total_spent                     156.66
#  average_purchasing_power             430.195
#  recency                                  507
#  frequency_normalized                0.175439
#  recency_normalized                  0.666214
#  total_spent                          7206.76
#  purchase_frequency                       261
#  unique_products                          194
#  normalized_f                        0.343915
#  normalized_r                        0.666214
#  combined_score                      0.537295
#  category_score                             1
#  business_score                      0.968863
#  score                               0.976647
#  bundle_id                   3441296_Bundle_3
#  is_anchor                                  0
#  Name: 9107, dtype: object,
#  consultant_id                        3441296
#  product_id                         200064341
#  category                    CUIDADO PERSONAL
#  brand                                  ESIKA
#  price                                  14.97
#  date                              2023-08-15
#  frequency                                 11
#  daily_total_spent                     156.66
#  average_purchasing_power             430.195
#  recency                                  507
#  frequency_normalized                0.175439
#  recency_normalized                  0.666214
#  total_spent                          7206.76
#  purchase_frequency                       261
#  unique_products                          194
#  normalized_f                        0.343915
#  normalized_r                        0.666214
#  combined_score                      0.537295
#  category_score                             1
#  business_score                      0.960777
#  score                               0.970583
#  bundle_id                   3441296_Bundle_3
#  is_anchor                                  0
#  Name: 9105, dtype: object,
#  consultant_id                        3441296
#  product_id                         200103449
#  category                    CUIDADO PERSONAL
#  brand                                 CYZONE
#  price                                   7.38
#  date                              2023-08-15
#  frequency                                 11
#  daily_total_spent                     156.66
#  average_purchasing_power             430.195
#  recency                                  507
#  frequency_normalized                0.175439
#  recency_normalized                  0.666214
#  total_spent                          7206.76
#  purchase_frequency                       261
#  unique_products                          194
#  normalized_f                        0.343915
#  normalized_r                        0.666214
#  combined_score                      0.537295
#  category_score                             1
#  business_score                      0.937514
#  score                               0.953135
#  bundle_id                   3441296_Bundle_3
#  is_anchor                                  0
#  Name: 13376, dtype: object,
#  consultant_id                        3441296
#  product_id                         200103025
#  category                    CUIDADO PERSONAL
#  brand                                  ESIKA
#  price                                  21.98
#  date                              2024-08-13
#  frequency                                 11
#  daily_total_spent                     344.28
#  average_purchasing_power             430.195
#  recency                                  143
#  frequency_normalized                0.175439
#  recency_normalized                   0.17232
#  total_spent                          7206.76
#  purchase_frequency                       261
#  unique_products                          194
#  normalized_f                        0.343915
#  normalized_r                         0.17232
#  combined_score                      0.240958
#  category_score                             1
#  business_score                      0.930813
#  score                                0.94811
#  bundle_id                   3441296_Bundle_3
#  is_anchor                                  0
#  Name: 12044, dtype: object,
#  consultant_id                        3441296
#  product_id                         200103448
#  category                    CUIDADO PERSONAL
#  brand                                  ESIKA
#  price                                   7.38
#  date                              2024-07-03
#  frequency                                 16
#  daily_total_spent                     354.53
#  average_purchasing_power             430.195
#  recency                                  184
#  frequency_normalized                0.263158
#  recency_normalized                  0.227951
#  total_spent                          7206.76
#  purchase_frequency                       261
#  unique_products                          194
#  normalized_f                        0.343915
#  normalized_r                        0.227951
#  combined_score                      0.274337
#  category_score                             1
#  business_score                      0.919345
#  score                               0.939509
#  bundle_id                   3441296_Bundle_3
#  is_anchor                                  0
#  Name: 21152, dtype: object,
#  consultant_id                        3441296
#  product_id                         200105188
#  category                    CUIDADO PERSONAL
#  brand                                  ESIKA
#  price                                  10.08
#  date                              2024-08-13
#  frequency                                 11
#  daily_total_spent                     344.28
#  average_purchasing_power             430.195
#  recency                                  143
#  frequency_normalized                0.175439
#  recency_normalized                   0.17232
#  total_spent                          7206.76
#  purchase_frequency                       261
#  unique_products                          194
#  normalized_f                        0.343915
#  normalized_r                         0.17232
#  combined_score                      0.240958
#  category_score                             1
#  business_score                      0.908135
#  score                               0.931101
#  bundle_id                   3441296_Bundle_3
#  is_anchor                                  0
#  Name: 12022, dtype: object,
#  consultant_id                        3441296
#  product_id                         200095159
#  category                    CUIDADO PERSONAL
#  brand                                  ESIKA
#  price                                   7.38
#  date                              2022-12-27
#  frequency                                 10
#  daily_total_spent                      263.4
#  average_purchasing_power             430.195
#  recency                                  738
#  frequency_normalized                0.157895
#  recency_normalized                  0.979647
#  total_spent                          7206.76
#  purchase_frequency                       261
#  unique_products                          194
#  normalized_f                        0.343915
#  normalized_r                        0.979647
#  combined_score                      0.725354
#  bundle_id                   3441296_Bundle_4
#  is_anchor                                  1
#  Name: 1793, dtype: object,
#  consultant_id                        3441296
#  product_id                         200078924
#  category                    CUIDADO PERSONAL
#  brand                                  ESIKA
#  price                                   16.9
#  date                              2024-07-03
#  frequency                                 16
#  daily_total_spent                     354.53
#  average_purchasing_power             430.195
#  recency                                  184
#  frequency_normalized                0.263158
#  recency_normalized                  0.227951
#  total_spent                          7206.76
#  purchase_frequency                       261
#  unique_products                          194
#  normalized_f                        0.343915
#  normalized_r                        0.227951
#  combined_score                      0.274337
#  category_score                             1
#  business_score                      0.994047
#  score                               0.995535
#  bundle_id                   3441296_Bundle_4
#  is_anchor                                  0
#  Name: 3122, dtype: object,
#  consultant_id                        3441296
#  product_id                         200115170
#  category                    CUIDADO PERSONAL
#  brand                                  ESIKA
#  price                                   24.9
#  date                              2024-06-10
#  frequency                                 14
#  daily_total_spent                     332.99
#  average_purchasing_power             430.195
#  recency                                  207
#  frequency_normalized                 0.22807
#  recency_normalized                  0.259159
#  total_spent                          7206.76
#  purchase_frequency                       261
#  unique_products                          194
#  normalized_f                        0.343915
#  normalized_r                        0.259159
#  combined_score                      0.293061
#  category_score                             1
#  business_score                      0.987939
#  score                               0.990955
#  bundle_id                   3441296_Bundle_4
#  is_anchor                                  0
#  Name: 35155, dtype: object,
#  consultant_id                        3441296
#  product_id                         200090349
#  category                    CUIDADO PERSONAL
#  brand                                  ESIKA
#  price                                   23.9
#  date                              2023-02-15
#  frequency                                  1
#  daily_total_spent                       23.9
#  average_purchasing_power             430.195
#  recency                                  688
#  frequency_normalized                     0.0
#  recency_normalized                  0.911805
#  total_spent                          7206.76
#  purchase_frequency                       261
#  unique_products                          194
#  normalized_f                        0.343915
#  normalized_r                        0.911805
#  combined_score                      0.684649
#  category_score                             1
#  business_score                      0.978679
#  score                                0.98401
#  bundle_id                   3441296_Bundle_4
#  is_anchor                                  0
#  Name: 20107, dtype: object,
#  consultant_id                        3441296
#  product_id                         200095430
#  category                    CUIDADO PERSONAL
#  brand                                 CYZONE
#  price                                   6.69
#  date                              2023-04-11
#  frequency                                 17
#  daily_total_spent                      391.1
#  average_purchasing_power             430.195
#  recency                                  633
#  frequency_normalized                0.280702
#  recency_normalized                  0.837178
#  total_spent                          7206.76
#  purchase_frequency                       261
#  unique_products                          194
#  normalized_f                        0.343915
#  normalized_r                        0.837178
#  combined_score                      0.639873
#  category_score                             1
#  business_score                      0.972123
#  score                               0.979092
#  bundle_id                   3441296_Bundle_4
#  is_anchor                                  0
#  Name: 10832, dtype: object,
#  consultant_id                        3441296
#  product_id                         200105125
#  category                    CUIDADO PERSONAL
#  brand                                  ESIKA
#  price                                   7.38
#  date                              2024-07-03
#  frequency                                 16
#  daily_total_spent                     354.53
#  average_purchasing_power             430.195
#  recency                                  184
#  frequency_normalized                0.263158
#  recency_normalized                  0.227951
#  total_spent                          7206.76
#  purchase_frequency                       261
#  unique_products                          194
#  normalized_f                        0.343915
#  normalized_r                        0.227951
#  combined_score                      0.274337
#  category_score                             1
#  business_score                      0.958197
#  score                               0.968648
#  bundle_id                   3441296_Bundle_4
#  is_anchor                                  0
#  Name: 35407, dtype: object,
#  consultant_id                        3441296
#  product_id                         200095465
#  category                    CUIDADO PERSONAL
#  brand                                  ESIKA
#  price                                   11.9
#  date                              2023-06-08
#  frequency                                 16
#  daily_total_spent                      385.9
#  average_purchasing_power             430.195
#  recency                                  575
#  frequency_normalized                0.263158
#  recency_normalized                   0.75848
#  total_spent                          7206.76
#  purchase_frequency                       261
#  unique_products                          194
#  normalized_f                        0.343915
#  normalized_r                         0.75848
#  combined_score                      0.592654
#  category_score                             1
#  business_score                       0.94967
#  score                               0.962252
#  bundle_id                   3441296_Bundle_4
#  is_anchor                                  0
#  Name: 22714, dtype: object,
#  consultant_id                        4623541
#  product_id                         200101587
#  category                          MAQUILLAJE
#  brand                                  ESIKA
#  price                                   17.9
#  date                              2022-12-27
#  frequency                                 11
#  daily_total_spent                      133.3
#  average_purchasing_power             430.195
#  recency                                  738
#  frequency_normalized                0.175439
#  recency_normalized                  0.979647
#  total_spent                          4624.35
#  purchase_frequency                       181
#  unique_products                          151
#  normalized_f                        0.238095
#  normalized_r                        0.979647
#  combined_score                      0.683026
#  bundle_id                   4623541_Bundle_1
#  is_anchor                                  1
#  Name: 4569, dtype: object,
#  consultant_id                        4623541
#  product_id                         210096207
#  category                          MAQUILLAJE
#  brand                                  ESIKA
#  price                                  16.95
#  date                              2023-03-17
#  frequency                                 22
#  daily_total_spent                     476.75
#  average_purchasing_power             430.195
#  recency                                  658
#  frequency_normalized                0.368421
#  recency_normalized                  0.871099
#  total_spent                          4624.35
#  purchase_frequency                       181
#  unique_products                          151
#  normalized_f                        0.238095
#  normalized_r                        0.871099
#  combined_score                      0.617898
#  category_score                             1
#  business_score                      0.982235
#  score                               0.986676
#  bundle_id                   4623541_Bundle_1
#  is_anchor                                  0
#  Name: 10499, dtype: object,
#  consultant_id                        4623541
#  product_id                         200107349
#  category                          MAQUILLAJE
#  brand                                 CYZONE
#  price                                   13.9
#  date                              2023-02-27
#  frequency                                 17
#  daily_total_spent                      321.5
#  average_purchasing_power             430.195
#  recency                                  676
#  frequency_normalized                0.280702
#  recency_normalized                  0.895522
#  total_spent                          4624.35
#  purchase_frequency                       181
#  unique_products                          151
#  normalized_f                        0.238095
#  normalized_r                        0.895522
#  combined_score                      0.632552
#  category_score                             1
#  business_score                      0.980865
#  score                               0.985649
#  bundle_id                   4623541_Bundle_1
#  is_anchor                                  0
#  Name: 13129, dtype: object,
#  consultant_id                        4623541
#  product_id                         200103920
#  category                          MAQUILLAJE
#  brand                                 CYZONE
#  price                                   11.6
#  date                              2023-03-17
#  frequency                                 22
#  daily_total_spent                     476.75
#  average_purchasing_power             430.195
#  recency                                  658
#  frequency_normalized                0.368421
#  recency_normalized                  0.871099
#  total_spent                          4624.35
#  purchase_frequency                       181
#  unique_products                          151
#  normalized_f                        0.238095
#  normalized_r                        0.871099
#  combined_score                      0.617898
#  category_score                             1
#  business_score                      0.975484
#  score                               0.981613
#  bundle_id                   4623541_Bundle_1
#  is_anchor                                  0
#  Name: 19593, dtype: object,
#  consultant_id                        4623541
#  product_id                         210096264
#  category                          MAQUILLAJE
#  brand                                  ESIKA
#  price                                   23.9
#  date                              2022-12-27
#  frequency                                 11
#  daily_total_spent                      133.3
#  average_purchasing_power             430.195
#  recency                                  738
#  frequency_normalized                0.175439
#  recency_normalized                  0.979647
#  total_spent                          4624.35
#  purchase_frequency                       181
#  unique_products                          151
#  normalized_f                        0.238095
#  normalized_r                        0.979647
#  combined_score                      0.683026
#  category_score                             1
#  business_score                      0.953365
#  score                               0.965024
#  bundle_id                   4623541_Bundle_1
#  is_anchor                                  0
#  Name: 23922, dtype: object,
#  consultant_id                        4623541
#  product_id                         210095652
#  category                          MAQUILLAJE
#  brand                                 CYZONE
#  price                                   11.9
#  date                              2023-01-20
#  frequency                                 24
#  daily_total_spent                      457.7
#  average_purchasing_power             430.195
#  recency                                  714
#  frequency_normalized                0.403509
#  recency_normalized                  0.947083
#  total_spent                          4624.35
#  purchase_frequency                       181
#  unique_products                          151
#  normalized_f                        0.238095
#  normalized_r                        0.947083
#  combined_score                      0.663488
#  category_score                             1
#  business_score                      0.915578
#  score                               0.936684
#  bundle_id                   4623541_Bundle_1
#  is_anchor                                  0
#  Name: 31736, dtype: object,
#  consultant_id                        4623541
#  product_id                         200101587
#  category                          MAQUILLAJE
#  brand                                  ESIKA
#  price                                   17.9
#  date                              2022-12-27
#  frequency                                 11
#  daily_total_spent                      133.3
#  average_purchasing_power             430.195
#  recency                                  738
#  frequency_normalized                0.175439
#  recency_normalized                  0.979647
#  total_spent                          4624.35
#  purchase_frequency                       181
#  unique_products                          151
#  normalized_f                        0.238095
#  normalized_r                        0.979647
#  combined_score                      0.683026
#  bundle_id                   4623541_Bundle_2
#  is_anchor                                  1
#  Name: 4569, dtype: object,
#  consultant_id                        4623541
#  product_id                         200107183
#  category                          MAQUILLAJE
#  brand                                 CYZONE
#  price                                   11.6
#  date                              2023-03-17
#  frequency                                 22
#  daily_total_spent                     476.75
#  average_purchasing_power             430.195
#  recency                                  658
#  frequency_normalized                0.368421
#  recency_normalized                  0.871099
#  total_spent                          4624.35
#  purchase_frequency                       181
#  unique_products                          151
#  normalized_f                        0.238095
#  normalized_r                        0.871099
#  combined_score                      0.617898
#  category_score                             1
#  business_score                       0.98018
#  score                               0.985135
#  bundle_id                   4623541_Bundle_2
#  is_anchor                                  0
#  Name: 32724, dtype: object,
#  consultant_id                        4623541
#  product_id                         200103354
#  category                          MAQUILLAJE
#  brand                                  ESIKA
#  price                                    9.0
#  date                              2023-03-17
#  frequency                                 22
#  daily_total_spent                     476.75
#  average_purchasing_power             430.195
#  recency                                  658
#  frequency_normalized                0.368421
#  recency_normalized                  0.871099
#  total_spent                          4624.35
#  purchase_frequency                       181
#  unique_products                          151
#  normalized_f                        0.238095
#  normalized_r                        0.871099
#  combined_score                      0.617898
#  category_score                             1
#  business_score                      0.974311
#  score                               0.980733
#  bundle_id                   4623541_Bundle_2
#  is_anchor                                  0
#  Name: 11083, dtype: object,
#  consultant_id                        4623541
#  product_id                         200100052
#  category                          MAQUILLAJE
#  brand                                  ESIKA
#  price                                   35.9
#  date                              2023-02-06
#  frequency                                 19
#  daily_total_spent                      558.3
#  average_purchasing_power             430.195
#  recency                                  697
#  frequency_normalized                0.315789
#  recency_normalized                  0.924016
#  total_spent                          4624.35
#  purchase_frequency                       181
#  unique_products                          151
#  normalized_f                        0.238095
#  normalized_r                        0.924016
#  combined_score                      0.649648
#  category_score                             1
#  business_score                      0.972176
#  score                               0.979132
#  bundle_id                   4623541_Bundle_2
#  is_anchor                                  0
#  Name: 302, dtype: object,
#  consultant_id                        4623541
#  product_id                         200094876
#  category                          MAQUILLAJE
#  brand                                  ESIKA
#  price                                   15.9
#  date                              2023-04-08
#  frequency                                 19
#  daily_total_spent                      564.4
#  average_purchasing_power             430.195
#  recency                                  636
#  frequency_normalized                0.315789
#  recency_normalized                  0.841248
#  total_spent                          4624.35
#  purchase_frequency                       181
#  unique_products                          151
#  normalized_f                        0.238095
#  normalized_r                        0.841248
#  combined_score                      0.599987
#  category_score                             1
#  business_score                      0.937748
#  score                               0.953311
#  bundle_id                   4623541_Bundle_2
#  is_anchor                                  0
#  Name: 10488, dtype: object,
#  consultant_id                        4623541
#  product_id                         200101587
#  category                          MAQUILLAJE
#  brand                                  ESIKA
#  price                                   17.9
#  date                              2022-12-27
#  frequency                                 11
#  daily_total_spent                      133.3
#  average_purchasing_power             430.195
#  recency                                  738
#  frequency_normalized                0.175439
#  recency_normalized                  0.979647
#  total_spent                          4624.35
#  purchase_frequency                       181
#  unique_products                          151
#  normalized_f                        0.238095
#  normalized_r                        0.979647
#  combined_score                      0.683026
#  bundle_id                   4623541_Bundle_3
#  is_anchor                                  1
#  Name: 4569, dtype: object,
#  consultant_id                        4623541
#  product_id                         210096264
#  category                          MAQUILLAJE
#  brand                                  ESIKA
#  price                                   23.9
#  date                              2022-12-27
#  frequency                                 11
#  daily_total_spent                      133.3
#  average_purchasing_power             430.195
#  recency                                  738
#  frequency_normalized                0.175439
#  recency_normalized                  0.979647
#  total_spent                          4624.35
#  purchase_frequency                       181
#  unique_products                          151
#  normalized_f                        0.238095
#  normalized_r                        0.979647
#  combined_score                      0.683026
#  category_score                             1
#  business_score                      0.985566
#  score                               0.989174
#  bundle_id                   4623541_Bundle_3
#  is_anchor                                  0
#  Name: 23922, dtype: object,
#  consultant_id                        4623541
#  product_id                         200109169
#  category                          MAQUILLAJE
#  brand                                 CYZONE
#  price                                   17.9
#  date                              2023-04-28
#  frequency                                 12
#  daily_total_spent                      483.9
#  average_purchasing_power             430.195
#  recency                                  616
#  frequency_normalized                0.192982
#  recency_normalized                  0.814111
#  total_spent                          4624.35
#  purchase_frequency                       181
#  unique_products                          151
#  normalized_f                        0.238095
#  normalized_r                        0.814111
#  combined_score                      0.583705
#  category_score                             1
#  business_score                      0.973254
#  score                               0.979941
#  bundle_id                   4623541_Bundle_3
#  is_anchor                                  0
#  Name: 13076, dtype: object,
#  consultant_id                        4623541
#  product_id                         200106452
#  category                          MAQUILLAJE
#  brand                                  ESIKA
#  price                                   19.9
#  date                              2023-08-02
#  frequency                                 15
#  daily_total_spent                      452.9
#  average_purchasing_power             430.195
#  recency                                  520
#  frequency_normalized                0.245614
#  recency_normalized                  0.683853
#  total_spent                          4624.35
#  purchase_frequency                       181
#  unique_products                          151
#  normalized_f                        0.238095
#  normalized_r                        0.683853
#  combined_score                       0.50555
#  category_score                             1
#  business_score                      0.959787
#  score                                0.96984
#  bundle_id                   4623541_Bundle_3
#  is_anchor                                  0
#  Name: 23331, dtype: object,
#  consultant_id                        4623541
#  product_id                         200103354
#  category                          MAQUILLAJE
#  brand                                  ESIKA
#  price                                   12.9
#  date                              2023-08-02
#  frequency                                 15
#  daily_total_spent                      452.9
#  average_purchasing_power             430.195
#  recency                                  520
#  frequency_normalized                0.245614
#  recency_normalized                  0.683853
#  total_spent                          4624.35
#  purchase_frequency                       181
#  unique_products                          151
#  normalized_f                        0.238095
#  normalized_r                        0.683853
#  combined_score                       0.50555
#  category_score                             1
#  business_score                      0.947189
#  score                               0.960391
#  bundle_id                   4623541_Bundle_3
#  is_anchor                                  0
#  Name: 32891, dtype: object,
#  consultant_id                        4623541
#  product_id                         200101587
#  category                          MAQUILLAJE
#  brand                                  ESIKA
#  price                                   17.9
#  date                              2022-12-27
#  frequency                                 11
#  daily_total_spent                      133.3
#  average_purchasing_power             430.195
#  recency                                  738
#  frequency_normalized                0.175439
#  recency_normalized                  0.979647
#  total_spent                          4624.35
#  purchase_frequency                       181
#  unique_products                          151
#  normalized_f                        0.238095
#  normalized_r                        0.979647
#  combined_score                      0.683026
#  bundle_id                   4623541_Bundle_4
#  is_anchor                                  1
#  Name: 4569, dtype: object,
#  consultant_id                        4623541
#  product_id                         200106556
#  category                          MAQUILLAJE
#  brand                                 CYZONE
# ...
#  daily_total_spent                      423.05
#  average_purchasing_power              430.195
#  recency                                   410
#  frequency_normalized                 0.350877
#  recency_normalized                     0.5346
#  total_spent                           5949.54
#  purchase_frequency                        225
#  unique_products                           192
#  normalized_f                         0.296296
#  normalized_r                           0.5346
#  combined_score                       0.439278
#  category_score                              1
#  business_score                       0.447162
#  score                                0.585371
#  bundle_id                   44196425_Bundle_2
#  is_anchor                                   0
#  Name: 832, dtype: object,
#  consultant_id                        44196425
#  product_id                          200107374
#  category                           MAQUILLAJE
#  brand                                  CYZONE
#  price                                    13.9
#  date                               2023-01-03
#  frequency                                   7
#  daily_total_spent                       212.4
#  average_purchasing_power              430.195
#  recency                                   731
#  frequency_normalized                 0.105263
#  recency_normalized                   0.970149
#  total_spent                           5949.54
#  purchase_frequency                        225
#  unique_products                           192
#  normalized_f                         0.296296
#  normalized_r                         0.970149
#  combined_score                       0.700608
#  bundle_id                   44196425_Bundle_3
#  is_anchor                                   1
#  Name: 2353, dtype: object,
#  consultant_id                        44196425
#  product_id                          200107183
#  category                           MAQUILLAJE
#  brand                                  CYZONE
#  price                                    12.6
#  date                               2023-12-22
#  frequency                                  38
#  daily_total_spent                      726.86
#  average_purchasing_power              430.195
#  recency                                   378
#  frequency_normalized                 0.649123
#  recency_normalized                    0.49118
#  total_spent                           5949.54
#  purchase_frequency                        225
#  unique_products                           192
#  normalized_f                         0.296296
#  normalized_r                          0.49118
#  combined_score                       0.413227
#  category_score                              1
#  business_score                        0.99971
#  score                                0.999783
#  bundle_id                   44196425_Bundle_3
#  is_anchor                                   0
#  Name: 16510, dtype: object,
#  consultant_id                        44196425
#  product_id                          200112313
#  category                           MAQUILLAJE
#  brand                                  CYZONE
#  price                                    9.98
#  date                               2024-02-02
#  frequency                                  11
#  daily_total_spent                       272.0
#  average_purchasing_power              430.195
#  recency                                   336
#  frequency_normalized                 0.175439
#  recency_normalized                   0.434193
#  total_spent                           5949.54
#  purchase_frequency                        225
#  unique_products                           192
#  normalized_f                         0.296296
#  normalized_r                         0.434193
#  combined_score                       0.379034
#  category_score                              1
#  business_score                       0.978907
#  score                                 0.98418
#  bundle_id                   44196425_Bundle_3
#  is_anchor                                   0
#  Name: 34763, dtype: object,
#  consultant_id                        44196425
#  product_id                          210095994
#  category                           MAQUILLAJE
#  brand                                   ESIKA
#  price                                    18.9
#  date                               2023-02-03
#  frequency                                  15
#  daily_total_spent                       373.2
#  average_purchasing_power              430.195
#  recency                                   700
#  frequency_normalized                 0.245614
#  recency_normalized                   0.928087
#  total_spent                           5949.54
#  purchase_frequency                        225
#  unique_products                           192
#  normalized_f                         0.296296
#  normalized_r                         0.928087
#  combined_score                       0.675371
#  category_score                              1
#  business_score                       0.968589
#  score                                0.976442
#  bundle_id                   44196425_Bundle_3
#  is_anchor                                   0
#  Name: 11136, dtype: object,
#  consultant_id                        44196425
#  product_id                          210098832
#  category                           MAQUILLAJE
#  brand                                  CYZONE
#  price                                    32.9
#  date                               2023-12-22
#  frequency                                  38
#  daily_total_spent                      726.86
#  average_purchasing_power              430.195
#  recency                                   378
#  frequency_normalized                 0.649123
#  recency_normalized                    0.49118
#  total_spent                           5949.54
#  purchase_frequency                        225
#  unique_products                           192
#  normalized_f                         0.296296
#  normalized_r                          0.49118
#  combined_score                       0.413227
#  category_score                              1
#  business_score                       0.949435
#  score                                0.962076
#  bundle_id                   44196425_Bundle_3
#  is_anchor                                   0
#  Name: 11481, dtype: object,
#  consultant_id                        44196425
#  product_id                          200112480
#  category                           MAQUILLAJE
#  brand                                   ESIKA
#  price                                     9.9
#  date                               2023-11-20
#  frequency                                  21
#  daily_total_spent                      423.05
#  average_purchasing_power              430.195
#  recency                                   410
#  frequency_normalized                 0.350877
#  recency_normalized                     0.5346
#  total_spent                           5949.54
#  purchase_frequency                        225
#  unique_products                           192
#  normalized_f                         0.296296
#  normalized_r                           0.5346
#  combined_score                       0.439278
#  category_score                              1
#  business_score                       0.732884
#  score                                0.799663
#  bundle_id                   44196425_Bundle_3
#  is_anchor                                   0
#  Name: 854, dtype: object,
#  consultant_id                        44196425
#  product_id                          200107374
#  category                           MAQUILLAJE
#  brand                                  CYZONE
#  price                                    13.9
#  date                               2023-01-03
#  frequency                                   7
#  daily_total_spent                       212.4
#  average_purchasing_power              430.195
#  recency                                   731
#  frequency_normalized                 0.105263
#  recency_normalized                   0.970149
#  total_spent                           5949.54
#  purchase_frequency                        225
#  unique_products                           192
#  normalized_f                         0.296296
#  normalized_r                         0.970149
#  combined_score                       0.700608
#  bundle_id                   44196425_Bundle_4
#  is_anchor                                   1
#  Name: 2353, dtype: object,
#  consultant_id                        44196425
#  product_id                          200112313
#  category                           MAQUILLAJE
#  brand                                  CYZONE
#  price                                    9.98
#  date                               2024-02-02
#  frequency                                  11
#  daily_total_spent                       272.0
#  average_purchasing_power              430.195
#  recency                                   336
#  frequency_normalized                 0.175439
#  recency_normalized                   0.434193
#  total_spent                           5949.54
#  purchase_frequency                        225
#  unique_products                           192
#  normalized_f                         0.296296
#  normalized_r                         0.434193
#  combined_score                       0.379034
#  category_score                              1
#  business_score                       0.992118
#  score                                0.994089
#  bundle_id                   44196425_Bundle_4
#  is_anchor                                   0
#  Name: 34763, dtype: object,
#  consultant_id                        44196425
#  product_id                          210100496
#  category                           MAQUILLAJE
#  brand                                  CYZONE
#  price                                     8.9
#  date                               2024-01-12
#  frequency                                  21
#  daily_total_spent                       589.1
#  average_purchasing_power              430.195
#  recency                                   357
#  frequency_normalized                 0.350877
#  recency_normalized                   0.462687
#  total_spent                           5949.54
#  purchase_frequency                        225
#  unique_products                           192
#  normalized_f                         0.296296
#  normalized_r                         0.462687
#  combined_score                        0.39613
#  category_score                              1
#  business_score                       0.977004
#  score                                0.982753
#  bundle_id                   44196425_Bundle_4
#  is_anchor                                   0
#  Name: 11588, dtype: object,
#  consultant_id                        44196425
#  product_id                          210096235
#  category                           MAQUILLAJE
#  brand                                   ESIKA
#  price                                    18.9
#  date                               2023-02-03
#  frequency                                  15
#  daily_total_spent                       373.2
#  average_purchasing_power              430.195
#  recency                                   700
#  frequency_normalized                 0.245614
#  recency_normalized                   0.928087
#  total_spent                           5949.54
#  purchase_frequency                        225
#  unique_products                           192
#  normalized_f                         0.296296
#  normalized_r                         0.928087
#  combined_score                       0.675371
#  category_score                              1
#  business_score                       0.914348
#  score                                0.935761
#  bundle_id                   44196425_Bundle_4
#  is_anchor                                   0
#  Name: 1106, dtype: object,
#  consultant_id                        44196425
#  product_id                          200103922
#  category                           MAQUILLAJE
#  brand                                  CYZONE
#  price                                   11.98
#  date                               2023-02-03
#  frequency                                  15
#  daily_total_spent                       373.2
#  average_purchasing_power              430.195
#  recency                                   700
#  frequency_normalized                 0.245614
#  recency_normalized                   0.928087
#  total_spent                           5949.54
#  purchase_frequency                        225
#  unique_products                           192
#  normalized_f                         0.296296
#  normalized_r                         0.928087
#  combined_score                       0.675371
#  category_score                              1
#  business_score                       0.911277
#  score                                0.933458
#  bundle_id                   44196425_Bundle_4
#  is_anchor                                   0
#  Name: 15415, dtype: object,
#  consultant_id                        44196425
#  product_id                          200103354
#  category                           MAQUILLAJE
#  brand                                   ESIKA
#  price                                    24.9
#  date                               2023-04-14
#  frequency                                  19
#  daily_total_spent                       496.6
#  average_purchasing_power              430.195
#  recency                                   630
#  frequency_normalized                 0.315789
#  recency_normalized                   0.833107
#  total_spent                           5949.54
#  purchase_frequency                        225
#  unique_products                           192
#  normalized_f                         0.296296
#  normalized_r                         0.833107
#  combined_score                       0.618383
#  category_score                              1
#  business_score                       0.904499
#  score                                0.928374
#  bundle_id                   44196425_Bundle_4
#  is_anchor                                   0
#  Name: 32375, dtype: object,
#  consultant_id                        44196425
#  product_id                          200106455
#  category                           MAQUILLAJE
#  brand                                   ESIKA
#  price                                     5.0
#  date                               2023-11-20
#  frequency                                  21
#  daily_total_spent                      423.05
#  average_purchasing_power              430.195
#  recency                                   410
#  frequency_normalized                 0.350877
#  recency_normalized                     0.5346
#  total_spent                           5949.54
#  purchase_frequency                        225
#  unique_products                           192
#  normalized_f                         0.296296
#  normalized_r                           0.5346
#  combined_score                       0.439278
#  category_score                              1
#  business_score                       0.725304
#  score                                0.793978
#  bundle_id                   44196425_Bundle_4
#  is_anchor                                   0
#  Name: 832, dtype: object,
#  consultant_id                           44242133
#  product_id                             200112474
#  category                    TRATAMIENTO CORPORAL
#  brand                                       LBEL
#  price                                       45.0
#  date                                  2023-01-03
#  frequency                                     14
#  daily_total_spent                          397.0
#  average_purchasing_power                 430.195
#  recency                                      731
#  frequency_normalized                     0.22807
#  recency_normalized                      0.970149
#  total_spent                              1294.88
#  purchase_frequency                            46
#  unique_products                               44
#  normalized_f                            0.059524
#  normalized_r                            0.970149
#  combined_score                          0.605899
#  bundle_id                      44242133_Bundle_1
#  is_anchor                                      1
#  Name: 4762, dtype: object,
#  ...]

# %%
data = pd.DataFrame(bundles)
data.head()
# Out:
#        consultant_id  product_id          category  brand  price        date  \
# 1793         3441296   200095159  CUIDADO PERSONAL  ESIKA   7.38  2022-12-27
# 18988        3441296   200078931  CUIDADO PERSONAL  ESIKA  13.27  2023-06-08
# 27276        3441296   200064341  CUIDADO PERSONAL  ESIKA  21.90  2022-12-27
# 3149         3441296   200108807  CUIDADO PERSONAL  ESIKA   7.38  2024-07-03
# 22714        3441296   200095465  CUIDADO PERSONAL  ESIKA  11.90  2023-06-08
#
#        frequency  daily_total_spent  average_purchasing_power  recency  ...  \
# 1793          10             263.40                   430.195      738  ...
# 18988         16             385.90                   430.195      575  ...
# 27276         10             263.40                   430.195      738  ...
# 3149          16             354.53                   430.195      184  ...
# 22714         16             385.90                   430.195      575  ...
#
#        purchase_frequency  unique_products  normalized_f  normalized_r  \
# 1793                  261              194      0.343915      0.979647
# 18988                 261              194      0.343915      0.758480
# 27276                 261              194      0.343915      0.979647
# 3149                  261              194      0.343915      0.227951
# 22714                 261              194      0.343915      0.758480
#
#        combined_score         bundle_id  is_anchor  category_score  \
# 1793         0.725354  3441296_Bundle_1          1             NaN
# 18988        0.592654  3441296_Bundle_1          0             1.0
# 27276        0.725354  3441296_Bundle_1          0             1.0
# 3149         0.274337  3441296_Bundle_1          0             1.0
# 22714        0.592654  3441296_Bundle_1          0             1.0
#
#       business_score     score
# 1793             NaN       NaN
# 18988       0.984574  0.988431
# 27276       0.890042  0.917532
# 3149        0.884674  0.913505
# 22714       0.861828  0.896371
#
# [5 rows x 23 columns]

# %% [markdown]
# Save the DataFrame to a CSV file named ***bundels_data_1000_C.csv***.

# %%
data.to_csv('bundels_data_1000_C.csv', index=False)

# %%
# Loop over each column and print unique values
for column in df.columns:
    unique_values = df[column].unique()
    print(f"Unique values in column '{column}': {unique_values}")
